# %%
import tensorflow as tf

# %%
tf.keras.utils.get_file(
    "ridership.tgz",
    "https://github.com/ageron/data/raw/main/ridership.tgz",
    cache_dir=".",
    extract=True
)
# Out:
# Downloading data from https://github.com/ageron/data/raw/main/ridership.tgz
# 108512/108512 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# '.\\datasets\\ridership.tgz'

# %%
import pandas as pd
from pathlib import Path

path = Path("datasets/ridership/CTA_-_Ridership_-_Daily_Boarding_Totals.csv")
df = pd.read_csv(path, parse_dates=["service_date"])
df.columns = ["date", "day_type", "bus", "rail", "total"]  # shorter names
df = df.sort_values("date").set_index("date")
df = df.drop("total", axis=1)  # no need for total, it's just bus + rail
df = df.drop_duplicates()  # remove duplicated months (2011-10 and 2014-07)

# %%
df
# Out:
#            day_type     bus    rail
# date
# 2001-01-01        U  297192  126455
# 2001-01-02        W  780827  501952
# 2001-01-03        W  824923  536432
# 2001-01-04        W  870021  550011
# 2001-01-05        W  890426  557917
# ...             ...     ...     ...
# 2021-11-26        W  257700  189694
# 2021-11-27        A  237839  187065
# 2021-11-28        U  184817  147830
# 2021-11-29        W  421322  276090
# 2021-11-30        W  450230  302349
#
# [7639 rows x 3 columns]

# %%
from pathlib import Path

IMAGES_PATH = Path() / "images" / "rnn"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import matplotlib.pyplot as plt

df["2019-03":"2019-05"].plot(grid=True, marker=".", figsize=(8, 3.5))
save_fig("daily_ridership_plot")  # extra code – saves the figure for the book
plt.show()

# %%
rail_train = df["rail"]["2016-01":"2018-12"] / 1e6
rail_valid = df["rail"]["2019-01":"2019-05"] / 1e6
rail_test = df["rail"]["2019-06":] / 1e6

# %%
seq_length = 56
tf.random.set_seed(42)  # extra code – ensures reproducibility
train_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_train.to_numpy(),
    targets=rail_train[seq_length:],
    sequence_length=seq_length,
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_valid.to_numpy(),
    targets=rail_valid[seq_length:],
    sequence_length=seq_length,
    batch_size=32
)

# %%
def fit_and_evaluate(model, train_set, valid_set, learning_rate, epochs=500):
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=50, restore_best_weights=True)
    opt = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
    model.compile(loss=tf.keras.losses.Huber(), optimizer=opt, metrics=["mae"])
    history = model.fit(train_set, validation_data=valid_set, epochs=epochs,
                        callbacks=[early_stopping_cb])
    valid_loss, valid_mae = model.evaluate(valid_set)
    return valid_mae * 1e6

# %%
tf.random.set_seed(42)
model=tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=[None,1]))
model.add(tf.keras.layers.SimpleRNN(32))
model.add(tf.keras.layers.Dense(1))
'''
model.add(tf.keras.layers.Dense(1,activation='tanh'))
model.add(tf.keras.layers.Lambda(lambda x:x+1))'''
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)             │ (None, 32)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
fit_and_evaluate(model, train_ds, valid_ds, learning_rate=0.02)
# Out:
# Epoch 1/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0916 - mae: 0.3408 - val_loss: 0.0047 - val_mae: 0.0711
# Epoch 2/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055 - mae: 0.0742 - val_loss: 0.0019 - val_mae: 0.0361
# Epoch 3/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mae: 0.0566 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 4/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - mae: 0.0555 - val_loss: 0.0024 - val_mae: 0.0425
# Epoch 5/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - mae: 0.0525 - val_loss: 0.0020 - val_mae: 0.0360
# Epoch 6/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0499 - val_loss: 0.0020 - val_mae: 0.0324
# Epoch 7/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0501 - val_loss: 0.0020 - val_mae: 0.0344
# Epoch 8/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mae: 0.0510 - val_loss: 0.0019 - val_mae: 0.0314
# Epoch 9/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mae: 0.0504 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 10/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mae: 0.0497 - val_loss: 0.0019 - val_mae: 0.0328
# Epoch 11/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mae: 0.0466 - val_loss: 0.0018 - val_mae: 0.0310
# Epoch 12/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0466 - val_loss: 0.0020 - val_mae: 0.0354
# Epoch 13/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - mae: 0.0456 - val_loss: 0.0021 - val_mae: 0.0358
# Epoch 14/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0444 - val_loss: 0.0019 - val_mae: 0.0356
# Epoch 15/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - mae: 0.0462 - val_loss: 0.0020 - val_mae: 0.0346
# Epoch 16/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0441 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 17/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - mae: 0.0461 - val_loss: 0.0019 - val_mae: 0.0338
# Epoch 18/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0450 - val_loss: 0.0019 - val_mae: 0.0351
# Epoch 19/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0453 - val_loss: 0.0020 - val_mae: 0.0335
# Epoch 20/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mae: 0.0453 - val_loss: 0.0018 - val_mae: 0.0306
# Epoch 21/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mae: 0.0474 - val_loss: 0.0019 - val_mae: 0.0354
# Epoch 22/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0449 - val_loss: 0.0021 - val_mae: 0.0359
# Epoch 23/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0443 - val_loss: 0.0020 - val_mae: 0.0314
# Epoch 24/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0420 - val_loss: 0.0018 - val_mae: 0.0294
# Epoch 25/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - mae: 0.0432 - val_loss: 0.0019 - val_mae: 0.0331
# Epoch 26/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mae: 0.0422 - val_loss: 0.0020 - val_mae: 0.0332
# Epoch 27/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mae: 0.0473 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 28/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mae: 0.0421 - val_loss: 0.0019 - val_mae: 0.0318
# Epoch 29/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0429 - val_loss: 0.0020 - val_mae: 0.0311
# Epoch 30/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mae: 0.0403 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 31/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - mae: 0.0435 - val_loss: 0.0019 - val_mae: 0.0338
# Epoch 32/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mae: 0.0460 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 33/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - mae: 0.0405 - val_loss: 0.0019 - val_mae: 0.0359
# Epoch 34/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mae: 0.0442 - val_loss: 0.0018 - val_mae: 0.0330
# Epoch 35/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0430 - val_loss: 0.0019 - val_mae: 0.0351
# Epoch 36/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0426 - val_loss: 0.0020 - val_mae: 0.0363
# Epoch 37/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0442 - val_loss: 0.0018 - val_mae: 0.0306
# Epoch 38/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0417 - val_loss: 0.0018 - val_mae: 0.0331
# Epoch 39/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0413 - val_loss: 0.0019 - val_mae: 0.0341
# Epoch 40/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - mae: 0.0393 - val_loss: 0.0018 - val_mae: 0.0336
# Epoch 41/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - mae: 0.0412 - val_loss: 0.0020 - val_mae: 0.0345
# Epoch 42/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0447 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 43/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0419 - val_loss: 0.0018 - val_mae: 0.0344
# Epoch 44/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mae: 0.0395 - val_loss: 0.0020 - val_mae: 0.0386
# Epoch 45/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0420 - val_loss: 0.0019 - val_mae: 0.0333
# Epoch 46/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0390 - val_loss: 0.0018 - val_mae: 0.0303
# Epoch 47/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0435 - val_loss: 0.0018 - val_mae: 0.0298
# Epoch 48/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mae: 0.0394 - val_loss: 0.0019 - val_mae: 0.0369
# Epoch 49/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mae: 0.0425 - val_loss: 0.0018 - val_mae: 0.0316
# Epoch 50/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mae: 0.0414 - val_loss: 0.0018 - val_mae: 0.0314
# Epoch 51/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0437 - val_loss: 0.0022 - val_mae: 0.0399
# Epoch 52/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0433 - val_loss: 0.0019 - val_mae: 0.0343
# Epoch 53/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0398 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 54/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0018 - val_mae: 0.0336
# Epoch 55/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0423 - val_loss: 0.0018 - val_mae: 0.0323
# Epoch 56/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0418 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 57/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mae: 0.0397 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 58/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0416 - val_loss: 0.0018 - val_mae: 0.0299
# Epoch 59/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0406 - val_loss: 0.0019 - val_mae: 0.0340
# Epoch 60/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0018 - val_mae: 0.0335
# Epoch 61/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025 - mae: 0.0404 - val_loss: 0.0018 - val_mae: 0.0337
# Epoch 62/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0416 - val_loss: 0.0020 - val_mae: 0.0348
# Epoch 63/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0420 - val_loss: 0.0020 - val_mae: 0.0332
# Epoch 64/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027 - mae: 0.0406 - val_loss: 0.0019 - val_mae: 0.0316
# Epoch 65/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - mae: 0.0386 - val_loss: 0.0019 - val_mae: 0.0359
# Epoch 66/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - mae: 0.0420 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 67/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027 - mae: 0.0402 - val_loss: 0.0018 - val_mae: 0.0310
# Epoch 68/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022 - mae: 0.0377 - val_loss: 0.0019 - val_mae: 0.0311
# Epoch 69/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - mae: 0.0439 - val_loss: 0.0019 - val_mae: 0.0357
# Epoch 70/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0416 - val_loss: 0.0018 - val_mae: 0.0307
# Epoch 71/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0407 - val_loss: 0.0019 - val_mae: 0.0337
# Epoch 72/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027 - mae: 0.0425 - val_loss: 0.0019 - val_mae: 0.0319
# Epoch 73/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mae: 0.0397 - val_loss: 0.0018 - val_mae: 0.0319
# Epoch 74/500
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mae: 0.0399 - val_loss: 0.0019 - val_mae: 0.0323
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0274
# 29384.763911366463
